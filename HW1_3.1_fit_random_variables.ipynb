# %%
#Import all the required libraries
import os
import torch
import numpy as np
import torch.nn as nn
from PIL import Image
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.autograd import Variable
from torchvision import datasets, transforms

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'
torch.manual_seed(1)

# %%
def load_data(train_batch_size, test_batch_size):
    # Fetch training data: total 60000 samples
        
    trainset = datasets.MNIST('data', train = True, download = False, 
                transform = transforms.Compose([
                transforms.Resize((32,32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    temp = torch.tensor(np.random.randint(0, 10, (len(trainset)),))
    trainset.targets = temp
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=train_batch_size, shuffle=True)

    testset = datasets.MNIST('data', train = False, 
                transform = transforms.Compose([
                transforms.Resize((32, 32)),
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,))
                ]))
    test_loader = torch.utils.data.DataLoader(testset ,batch_size = test_batch_size, shuffle=True)

    return (train_loader, test_loader)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        # flatten as one dimension
        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        return x

# %%
train_batch_size = 100
test_batch_size = 100
train_loader, test_loader = load_data(train_batch_size, test_batch_size)

# %%
def train(model, optimizer, train_loader):
    model.train()
    correct = 0
    train_loss = 0
    counter = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        counter += 1
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()

        # Forward propagation
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.data

        pred = np.argmax(output.data, axis=1)
        correct += np.equal(pred, target.data).sum()
    
    train_loss = (train_loss * 100) / len(train_loader.dataset)
    acc = 100.0 * correct / len(train_loader.dataset)
    return train_loss, acc

# %%
def test(model, epoch, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    for data, target in test_loader:
        data, target = Variable(data), Variable(target)
        
        output = model(data)
        loss = loss_fn(output, target)
        test_loss += loss.data

        pred = np.argmax(output.data, axis = 1)
        correct = correct + np.equal(pred, target.data).sum()

    # Print log
    test_loss = (test_loss * 100) / len(test_loader.dataset)
    print('\nTest set, Epoch {} , Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(epoch,
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss

# %%
model = CNN()

optimizer = optim.Adam(model.parameters(), lr=0.0001)
m1_train_loss_arr = []
m1_test_loss_arr = []

epochs = 100
log_interval = 500
loss_fn = torch.nn.CrossEntropyLoss()
for epoch in range(1, epochs + 1):
    tr_loss, acc = train(model, optimizer, train_loader)
    m1_train_loss_arr.append(tr_loss)
    loss_test = test(model, epoch, test_loader)
    m1_test_loss_arr.append(loss_test)
    print('Epoch: ', epoch)
    print('Loss= ', tr_loss)
# Out:
# Test set, Epoch 1 , Average loss: 2.2997, Accuracy: 1153/10000 (12%)
#
# Epoch:  1
# Loss=  tensor(2.3031)
#
# Test set, Epoch 2 , Average loss: 2.3000, Accuracy: 1183/10000 (12%)
#
# Epoch:  2
# Loss=  tensor(2.3024)
#
# Test set, Epoch 3 , Average loss: 2.2987, Accuracy: 1084/10000 (11%)
#
# Epoch:  3
# Loss=  tensor(2.3019)
#
# Test set, Epoch 4 , Average loss: 2.2992, Accuracy: 1550/10000 (16%)
#
# Epoch:  4
# Loss=  tensor(2.3014)
#
# Test set, Epoch 5 , Average loss: 2.2946, Accuracy: 1030/10000 (10%)
#
# Epoch:  5
# Loss=  tensor(2.3008)
#
# Test set, Epoch 6 , Average loss: 2.2973, Accuracy: 1285/10000 (13%)
#
# Epoch:  6
# Loss=  tensor(2.3000)
#
# Test set, Epoch 7 , Average loss: 2.2933, Accuracy: 1489/10000 (15%)
#
# Epoch:  7
# Loss=  tensor(2.2989)
#
# Test set, Epoch 8 , Average loss: 2.2896, Accuracy: 1289/10000 (13%)
#
# Epoch:  8
# Loss=  tensor(2.2976)
#
# Test set, Epoch 9 , Average loss: 2.2942, Accuracy: 1262/10000 (13%)
#
# Epoch:  9
# Loss=  tensor(2.2961)
#
# Test set, Epoch 10 , Average loss: 2.2927, Accuracy: 1014/10000 (10%)
#
# Epoch:  10
# Loss=  tensor(2.2946)
#
# Test set, Epoch 11 , Average loss: 2.2832, Accuracy: 1540/10000 (15%)
#
# Epoch:  11
# Loss=  tensor(2.2925)
#
# Test set, Epoch 12 , Average loss: 2.2893, Accuracy: 1190/10000 (12%)
#
# Epoch:  12
# Loss=  tensor(2.2905)
#
# Test set, Epoch 13 , Average loss: 2.2857, Accuracy: 1224/10000 (12%)
#
# Epoch:  13
# Loss=  tensor(2.2882)
#
# Test set, Epoch 14 , Average loss: 2.2816, Accuracy: 1417/10000 (14%)
#
# Epoch:  14
# Loss=  tensor(2.2857)
#
# Test set, Epoch 15 , Average loss: 2.2956, Accuracy: 1127/10000 (11%)
#
# Epoch:  15
# Loss=  tensor(2.2832)
#
# Test set, Epoch 16 , Average loss: 2.2935, Accuracy: 1374/10000 (14%)
#
# Epoch:  16
# Loss=  tensor(2.2806)
#
# Test set, Epoch 17 , Average loss: 2.2944, Accuracy: 1207/10000 (12%)
#
# Epoch:  17
# Loss=  tensor(2.2774)
#
# Test set, Epoch 18 , Average loss: 2.2918, Accuracy: 1308/10000 (13%)
#
# Epoch:  18
# Loss=  tensor(2.2744)
#
# Test set, Epoch 19 , Average loss: 2.2917, Accuracy: 1201/10000 (12%)
#
# Epoch:  19
# Loss=  tensor(2.2716)
#
# Test set, Epoch 20 , Average loss: 2.3142, Accuracy: 1112/10000 (11%)
#
# Epoch:  20
# Loss=  tensor(2.2680)
#
# Test set, Epoch 21 , Average loss: 2.3078, Accuracy: 1171/10000 (12%)
#
# Epoch:  21
# Loss=  tensor(2.2648)
#
# Test set, Epoch 22 , Average loss: 2.3239, Accuracy: 1008/10000 (10%)
#
# Epoch:  22
# Loss=  tensor(2.2618)
#
# Test set, Epoch 23 , Average loss: 2.3000, Accuracy: 1282/10000 (13%)
#
# Epoch:  23
# Loss=  tensor(2.2580)
#
# Test set, Epoch 24 , Average loss: 2.3099, Accuracy: 1201/10000 (12%)
#
# Epoch:  24
# Loss=  tensor(2.2537)
#
# Test set, Epoch 25 , Average loss: 2.3086, Accuracy: 1112/10000 (11%)
#
# Epoch:  25
# Loss=  tensor(2.2504)
#
# Test set, Epoch 26 , Average loss: 2.3262, Accuracy: 1221/10000 (12%)
#
# Epoch:  26
# Loss=  tensor(2.2465)
#
# Test set, Epoch 27 , Average loss: 2.3178, Accuracy: 1167/10000 (12%)
#
# Epoch:  27
# Loss=  tensor(2.2425)
#
# Test set, Epoch 28 , Average loss: 2.3319, Accuracy: 1108/10000 (11%)
#
# Epoch:  28
# Loss=  tensor(2.2386)
#
# Test set, Epoch 29 , Average loss: 2.3070, Accuracy: 1254/10000 (13%)
#
# Epoch:  29
# Loss=  tensor(2.2349)
#
# Test set, Epoch 30 , Average loss: 2.3367, Accuracy: 1088/10000 (11%)
#
# Epoch:  30
# Loss=  tensor(2.2312)
#
# Test set, Epoch 31 , Average loss: 2.3306, Accuracy: 1090/10000 (11%)
#
# Epoch:  31
# Loss=  tensor(2.2273)
#
# Test set, Epoch 32 , Average loss: 2.3364, Accuracy: 1150/10000 (12%)
#
# Epoch:  32
# Loss=  tensor(2.2233)
#
# Test set, Epoch 33 , Average loss: 2.3210, Accuracy: 1180/10000 (12%)
#
# Epoch:  33
# Loss=  tensor(2.2190)
#
# Test set, Epoch 34 , Average loss: 2.3489, Accuracy: 1005/10000 (10%)
#
# Epoch:  34
# Loss=  tensor(2.2143)
#
# Test set, Epoch 35 , Average loss: 2.3654, Accuracy: 1037/10000 (10%)
#
# Epoch:  35
# Loss=  tensor(2.2105)
#
# Test set, Epoch 36 , Average loss: 2.3513, Accuracy: 1063/10000 (11%)
#
# Epoch:  36
# Loss=  tensor(2.2072)
#
# Test set, Epoch 37 , Average loss: 2.3620, Accuracy: 1030/10000 (10%)
#
# Epoch:  37
# Loss=  tensor(2.2026)
#
# Test set, Epoch 38 , Average loss: 2.3875, Accuracy: 875/10000 (9%)
#
# Epoch:  38
# Loss=  tensor(2.1988)
#
# Test set, Epoch 39 , Average loss: 2.3665, Accuracy: 1060/10000 (11%)
#
# Epoch:  39
# Loss=  tensor(2.1949)
#
# Test set, Epoch 40 , Average loss: 2.3565, Accuracy: 1089/10000 (11%)
#
# Epoch:  40
# Loss=  tensor(2.1909)
#
# Test set, Epoch 41 , Average loss: 2.4100, Accuracy: 917/10000 (9%)
#
# Epoch:  41
# Loss=  tensor(2.1865)
#
# Test set, Epoch 42 , Average loss: 2.4012, Accuracy: 1042/10000 (10%)
#
# Epoch:  42
# Loss=  tensor(2.1826)
#
# Test set, Epoch 43 , Average loss: 2.3749, Accuracy: 1143/10000 (11%)
#
# Epoch:  43
# Loss=  tensor(2.1783)
#
# Test set, Epoch 44 , Average loss: 2.3527, Accuracy: 1180/10000 (12%)
#
# Epoch:  44
# Loss=  tensor(2.1745)
#
# Test set, Epoch 45 , Average loss: 2.3746, Accuracy: 1155/10000 (12%)
#
# Epoch:  45
# Loss=  tensor(2.1701)
#
# Test set, Epoch 46 , Average loss: 2.3790, Accuracy: 1031/10000 (10%)
#
# Epoch:  46
# Loss=  tensor(2.1661)
#
# Test set, Epoch 47 , Average loss: 2.3946, Accuracy: 1091/10000 (11%)
#
# Epoch:  47
# Loss=  tensor(2.1607)
#
# Test set, Epoch 48 , Average loss: 2.3714, Accuracy: 1134/10000 (11%)
#
# Epoch:  48
# Loss=  tensor(2.1579)
#
# Test set, Epoch 49 , Average loss: 2.4385, Accuracy: 923/10000 (9%)
#
# Epoch:  49
# Loss=  tensor(2.1531)
#
# Test set, Epoch 50 , Average loss: 2.3782, Accuracy: 1087/10000 (11%)
#
# Epoch:  50
# Loss=  tensor(2.1494)
#
# Test set, Epoch 51 , Average loss: 2.4092, Accuracy: 1071/10000 (11%)
#
# Epoch:  51
# Loss=  tensor(2.1456)
#
# Test set, Epoch 52 , Average loss: 2.4235, Accuracy: 935/10000 (9%)
#
# Epoch:  52
# Loss=  tensor(2.1407)
#
# Test set, Epoch 53 , Average loss: 2.4177, Accuracy: 1017/10000 (10%)
#
# Epoch:  53
# Loss=  tensor(2.1384)
#
# Test set, Epoch 54 , Average loss: 2.4278, Accuracy: 1078/10000 (11%)
#
# Epoch:  54
# Loss=  tensor(2.1333)
#
# Test set, Epoch 55 , Average loss: 2.4289, Accuracy: 985/10000 (10%)
#
# Epoch:  55
# Loss=  tensor(2.1291)
#
# Test set, Epoch 56 , Average loss: 2.4308, Accuracy: 1091/10000 (11%)
#
# Epoch:  56
# Loss=  tensor(2.1254)
#
# Test set, Epoch 57 , Average loss: 2.4547, Accuracy: 1020/10000 (10%)
#
# Epoch:  57
# Loss=  tensor(2.1218)
#
# Test set, Epoch 58 , Average loss: 2.4361, Accuracy: 1056/10000 (11%)
#
# Epoch:  58
# Loss=  tensor(2.1174)
#
# Test set, Epoch 59 , Average loss: 2.4074, Accuracy: 1164/10000 (12%)
#
# Epoch:  59
# Loss=  tensor(2.1141)
#
# Test set, Epoch 60 , Average loss: 2.4660, Accuracy: 972/10000 (10%)
#
# Epoch:  60
# Loss=  tensor(2.1092)
#
# Test set, Epoch 61 , Average loss: 2.4496, Accuracy: 1046/10000 (10%)
#
# Epoch:  61
# Loss=  tensor(2.1057)
#
# Test set, Epoch 62 , Average loss: 2.4685, Accuracy: 979/10000 (10%)
#
# Epoch:  62
# Loss=  tensor(2.1014)
#
# Test set, Epoch 63 , Average loss: 2.4234, Accuracy: 1119/10000 (11%)
#
# Epoch:  63
# Loss=  tensor(2.0978)
#
# Test set, Epoch 64 , Average loss: 2.5012, Accuracy: 920/10000 (9%)
#
# Epoch:  64
# Loss=  tensor(2.0931)
#
# Test set, Epoch 65 , Average loss: 2.4899, Accuracy: 1048/10000 (10%)
#
# Epoch:  65
# Loss=  tensor(2.0894)
#
# Test set, Epoch 66 , Average loss: 2.4571, Accuracy: 1006/10000 (10%)
#
# Epoch:  66
# Loss=  tensor(2.0849)
#
# Test set, Epoch 67 , Average loss: 2.4956, Accuracy: 1016/10000 (10%)
#
# Epoch:  67
# Loss=  tensor(2.0824)
#
# Test set, Epoch 68 , Average loss: 2.4637, Accuracy: 1039/10000 (10%)
#
# Epoch:  68
# Loss=  tensor(2.0774)
#
# Test set, Epoch 69 , Average loss: 2.4903, Accuracy: 1033/10000 (10%)
#
# Epoch:  69
# Loss=  tensor(2.0749)
#
# Test set, Epoch 70 , Average loss: 2.4629, Accuracy: 1097/10000 (11%)
#
# Epoch:  70
# Loss=  tensor(2.0688)
#
# Test set, Epoch 71 , Average loss: 2.5156, Accuracy: 1034/10000 (10%)
#
# Epoch:  71
# Loss=  tensor(2.0660)
#
# Test set, Epoch 72 , Average loss: 2.5112, Accuracy: 957/10000 (10%)
#
# Epoch:  72
# Loss=  tensor(2.0636)
#
# Test set, Epoch 73 , Average loss: 2.4398, Accuracy: 1170/10000 (12%)
#
# Epoch:  73
# Loss=  tensor(2.0581)
#
# Test set, Epoch 74 , Average loss: 2.5166, Accuracy: 976/10000 (10%)
#
# Epoch:  74
# Loss=  tensor(2.0548)
#
# Test set, Epoch 75 , Average loss: 2.5014, Accuracy: 1022/10000 (10%)
#
# Epoch:  75
# Loss=  tensor(2.0512)
#
# Test set, Epoch 76 , Average loss: 2.5209, Accuracy: 1007/10000 (10%)
#
# Epoch:  76
# Loss=  tensor(2.0467)
#
# Test set, Epoch 77 , Average loss: 2.4916, Accuracy: 1054/10000 (11%)
#
# Epoch:  77
# Loss=  tensor(2.0448)
#
# Test set, Epoch 78 , Average loss: 2.5480, Accuracy: 965/10000 (10%)
#
# Epoch:  78
# Loss=  tensor(2.0391)
#
# Test set, Epoch 79 , Average loss: 2.5546, Accuracy: 944/10000 (9%)
#
# Epoch:  79
# Loss=  tensor(2.0363)
#
# Test set, Epoch 80 , Average loss: 2.5364, Accuracy: 993/10000 (10%)
#
# Epoch:  80
# Loss=  tensor(2.0331)
#
# Test set, Epoch 81 , Average loss: 2.4889, Accuracy: 1134/10000 (11%)
#
# Epoch:  81
# Loss=  tensor(2.0293)
#
# Test set, Epoch 82 , Average loss: 2.5198, Accuracy: 1026/10000 (10%)
#
# Epoch:  82
# Loss=  tensor(2.0250)
#
# Test set, Epoch 83 , Average loss: 2.5504, Accuracy: 1055/10000 (11%)
#
# Epoch:  83
# Loss=  tensor(2.0224)
#
# Test set, Epoch 84 , Average loss: 2.5945, Accuracy: 857/10000 (9%)
#
# Epoch:  84
# Loss=  tensor(2.0194)
#
# Test set, Epoch 85 , Average loss: 2.5344, Accuracy: 1034/10000 (10%)
#
# Epoch:  85
# Loss=  tensor(2.0153)
#
# Test set, Epoch 86 , Average loss: 2.5777, Accuracy: 937/10000 (9%)
#
# Epoch:  86
# Loss=  tensor(2.0104)
#
# Test set, Epoch 87 , Average loss: 2.5177, Accuracy: 1187/10000 (12%)
#
# Epoch:  87
# Loss=  tensor(2.0079)
#
# Test set, Epoch 88 , Average loss: 2.5513, Accuracy: 1069/10000 (11%)
#
# Epoch:  88
# Loss=  tensor(2.0047)
#
# Test set, Epoch 89 , Average loss: 2.5660, Accuracy: 1027/10000 (10%)
#
# Epoch:  89
# Loss=  tensor(2.0004)
#
# Test set, Epoch 90 , Average loss: 2.6229, Accuracy: 918/10000 (9%)
#
# Epoch:  90
# Loss=  tensor(1.9978)
#
# Test set, Epoch 91 , Average loss: 2.5543, Accuracy: 1033/10000 (10%)
#
# Epoch:  91
# Loss=  tensor(1.9938)
#
# Test set, Epoch 92 , Average loss: 2.5653, Accuracy: 1002/10000 (10%)
#
# Epoch:  92
# Loss=  tensor(1.9905)
#
# Test set, Epoch 93 , Average loss: 2.5926, Accuracy: 983/10000 (10%)
#
# Epoch:  93
# Loss=  tensor(1.9869)
#
# Test set, Epoch 94 , Average loss: 2.5840, Accuracy: 1008/10000 (10%)
#
# Epoch:  94
# Loss=  tensor(1.9841)
#
# Test set, Epoch 95 , Average loss: 2.5867, Accuracy: 1028/10000 (10%)
#
# Epoch:  95
# Loss=  tensor(1.9803)
#
# Test set, Epoch 96 , Average loss: 2.6238, Accuracy: 1007/10000 (10%)
#
# Epoch:  96
# Loss=  tensor(1.9789)
#
# Test set, Epoch 97 , Average loss: 2.5961, Accuracy: 1074/10000 (11%)
#
# Epoch:  97
# Loss=  tensor(1.9748)
#
# Test set, Epoch 98 , Average loss: 2.6050, Accuracy: 1123/10000 (11%)
#
# Epoch:  98
# Loss=  tensor(1.9697)
#
# Test set, Epoch 99 , Average loss: 2.5469, Accuracy: 1172/10000 (12%)
#
# Epoch:  99
# Loss=  tensor(1.9669)
#
# Test set, Epoch 100 , Average loss: 2.6616, Accuracy: 941/10000 (9%)
#
# Epoch:  100
# Loss=  tensor(1.9650)

# %%
temp_1 = []
for i in m1_train_loss_arr:
    temp_1.append(i.data.numpy().tolist())
temp_2 = []
for i in m1_test_loss_arr:
    temp_2.append(i.data.numpy().tolist())

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(0, 100, 1), temp_1, color = "red")
plt.plot(np.arange(0, 100, 1), temp_2, color = "blue")
plt.title('Model Loss Comparison')
plt.legend(['Train Loss', 'Test Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
model_param = CNN()
param = sum(p.numel() for p in model.parameters())
print(param)
# Out:
# 61706
